# %%
import os
import pandas as pd
import numpy as np

# %% [markdown]
# Data preparation
#
# import dataset

# %%
rating = pd.read_csv('D:/code/rating.csv')
rating.head(5)
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
anime0 = pd.read_csv('D:/code/anime.csv')
anime0.head(5)
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %% [markdown]
# EXTRACT FEATURE VECTOR FOR EACH ANIME

# %%
anime = anime0.drop(columns=['name','members','rating'])
anime
# Out:
#        anime_id                                              genre   type  \
# 0         32281               Drama, Romance, School, Supernatural  Movie
# 1          5114  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV
# 2         28977  Action, Comedy, Historical, Parody, Samurai, S...     TV
# 3          9253                                   Sci-Fi, Thriller     TV
# 4          9969  Action, Comedy, Historical, Parody, Samurai, S...     TV
# ...         ...                                                ...    ...
# 12289      9316                                             Hentai    OVA
# 12290      5543                                             Hentai    OVA
# 12291      5621                                             Hentai    OVA
# 12292      6133                                             Hentai    OVA
# 12293     26081                                             Hentai  Movie
#
#       episodes
# 0            1
# 1           64
# 2           51
# 3           24
# 4           51
# ...        ...
# 12289        1
# 12290        1
# 12291        4
# 12292        1
# 12293        1
#
# [12294 rows x 4 columns]

# %%
# spand genre in columns, one for each genre
def func(x):
    if x['genre'] is np.nan:
        return x
    else:
        genres = list(map(lambda y: y.strip(), x['genre'].split(',')))
        for g in genres:
            x[g] = 1
        return x


anime2 = anime.apply(func, axis=1)
anime2.head(5)
# Out:
#    Action  Adventure  Cars  Comedy  Dementia  Demons  Drama  Ecchi  Fantasy  \
# 0     NaN        NaN   NaN     NaN       NaN     NaN    1.0    NaN      NaN
# 1     1.0        1.0   NaN     NaN       NaN     NaN    1.0    NaN      1.0
# 2     1.0        NaN   NaN     1.0       NaN     NaN    NaN    NaN      NaN
# 3     NaN        NaN   NaN     NaN       NaN     NaN    NaN    NaN      NaN
# 4     1.0        NaN   NaN     1.0       NaN     NaN    NaN    NaN      NaN
#
#    Game  ...  Super Power  Supernatural  Thriller  Vampire  Yaoi  Yuri  \
# 0   NaN  ...          NaN           1.0       NaN      NaN   NaN   NaN
# 1   NaN  ...          NaN           NaN       NaN      NaN   NaN   NaN
# 2   NaN  ...          NaN           NaN       NaN      NaN   NaN   NaN
# 3   NaN  ...          NaN           NaN       1.0      NaN   NaN   NaN
# 4   NaN  ...          NaN           NaN       NaN      NaN   NaN   NaN
#
#    anime_id  episodes                                              genre  \
# 0     32281         1               Drama, Romance, School, Supernatural
# 1      5114        64  Action, Adventure, Drama, Fantasy, Magic, Mili...
# 2     28977        51  Action, Comedy, Historical, Parody, Samurai, S...
# 3      9253        24                                   Sci-Fi, Thriller
# 4      9969        51  Action, Comedy, Historical, Parody, Samurai, S...
#
#     type
# 0  Movie
# 1     TV
# 2     TV
# 3     TV
# 4     TV
#
# [5 rows x 47 columns]
